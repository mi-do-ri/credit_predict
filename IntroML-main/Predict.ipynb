# %% [markdown]
# Import thư viện

# %%
import pandas as pd
import numpy as np

from imblearn.over_sampling import SMOTE 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer
import category_encoders as ce

from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Đọc dữ liệu tập train, test

# %%
df = pd.read_csv("train.csv")
train_labels = df['Risk']
train_data = df.drop('Risk',axis = 'columns')
train_data.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   47    male    2    free             NaN           little           8335
# 1   38    male    2     own          little              NaN            804
# 2   28    male    2     own          little           little           5371
# 3   29  female    0     own             NaN         moderate           3990
# 4   24  female    2     own             NaN         moderate           8487
#
#    Duration              Purpose
# 0        36                  car
# 1        12             radio/TV
# 2        36  furniture/equipment
# 3        36  domestic appliances
# 4        48                  car

# %%
test_df = pd.read_csv("test.csv")
test_labels = test_df['Risk']
test_data = test_df.drop('Risk', axis='columns')
test_data
# Out:
#      Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     36  male    2     own            rich         moderate           1913
# 1     34  male    3     own          little         moderate           1860
# 2     48  male    2     own          little           little           1024
# 3     31  male    2     own          little           little           3104
# 4     23  male    1     own      quite rich         moderate           2520
# ..   ...   ...  ...     ...             ...              ...            ...
# 195   53  male    2    free          little           little           7119
# 196   42  male    2     own             NaN         moderate           2427
# 197   25  male    2     own          little              NaN           1262
# 198   31  male    2     own             NaN           little           6350
# 199   34  male    3     own        moderate              NaN           1591
#
#      Duration              Purpose
# 0          18             business
# 1          12                  car
# 2          24             radio/TV
# 3          18             business
# 4          27             radio/TV
# ..        ...                  ...
# 195        48  furniture/equipment
# 196        18             business
# 197        12             radio/TV
# 198        30  furniture/equipment
# 199        21  furniture/equipment
#
# [200 rows x 9 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               800 non-null    int64
#  1   Sex               800 non-null    object
#  2   Job               800 non-null    int64
#  3   Housing           800 non-null    object
#  4   Saving accounts   656 non-null    object
#  5   Checking account  484 non-null    object
#  6   Credit amount     800 non-null    int64
#  7   Duration          800 non-null    int64
#  8   Purpose           800 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 56.4+ KB

# %% [markdown]
# Thay thể giá trị missing là 'nan'

# %%
missing_value_cols = ['Saving accounts','Checking account']

# %%
train_data[missing_value_cols] = train_data[missing_value_cols].replace(np.nan,'nan')
test_data[missing_value_cols] = test_data[missing_value_cols].replace(np.nan,'nan')

# %%
train_data.dtypes
# Out:
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# dtype: object

# %%
# for value in train_data['Credit amount']:
#     if value > 10000: value = 10000


# train_data['Credit amount'] = train_data['Credit amount'].map(lambda x: 10000 if x > 10000 else x)
# train_data['Credit amount'] = np.log(train_data['Credit amount']+1)

# print(train_data['Credit amount'].unique())

# %% [markdown]
# Vì tỉ lệ rủi ro không tăng theo tuổi, nghề nghiệp nên từ dạng numeric đổi về dạng object

# %%
def age_transform(value):
    if value <= 29: value = 'Young'
    elif value <= 40 : value = 'Young_Adult'
    elif value <55: value = 'Adult'
    elif value <80: value = 'Elder'
    else:
        value = 'Diff'
    return value

train_data['Age'] = train_data['Age'].map(age_transform)
test_data['Age'] = test_data['Age'].map(age_transform)

# %%
def job_transform(value):
    if value == 0 : value = 'J0'
    elif value == 1 : value = 'J1'
    elif value == 2: value = 'J2'
    elif value == 3 : value = 'J3'
    else: value = 'Diff'
    return value

train_data['Job'] = train_data['Job'].map(job_transform)
test_data['Job'] = test_data['Job'].map(job_transform)

# %%
numeric_cols = ['Credit amount','Duration']
categorical_cols = ['Job','Sex','Housing','Saving accounts','Checking account','Purpose', 'Age']

# %% [markdown]
# Encode lại các cột object theo tỉ lệ rủi ro trên tập train

# %%
encoder = ce.TargetEncoder(categorical_cols)
encoder.fit(X=train_data, y= train_labels)
train_data= encoder.transform(train_data)
test_data = encoder.transform(test_data)
# Out:
# c:\Python\Python310\lib\site-packages\category_encoders\target_encoder.py:122: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# c:\Python\Python310\lib\site-packages\category_encoders\target_encoder.py:127: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."

# %%
train_data
# Out:
#           Age       Sex       Job   Housing  Saving accounts  \
# 0    0.256579  0.274047  0.289628  0.406977         0.166667
# 1    0.261745  0.274047  0.289628  0.259649         0.364211
# 2    0.352740  0.274047  0.289628  0.259649         0.364211
# 3    0.352740  0.357430  0.375000  0.259649         0.166667
# 4    0.352740  0.357430  0.289628  0.259649         0.166667
# ..        ...       ...       ...       ...              ...
# 795  0.352740  0.357430  0.289628  0.259649         0.333333
# 796  0.256579  0.274047  0.289628  0.406977         0.364211
# 797  0.256579  0.274047  0.289628  0.259649         0.364211
# 798  0.352740  0.357430  0.289628  0.395833         0.166667
# 799  0.261745  0.274047  0.289628  0.259649         0.364211
#
#      Checking account  Credit amount  Duration   Purpose
# 0            0.479452           8335        36  0.309353
# 1            0.120253            804        12  0.213953
# 2            0.479452           5371        36  0.328859
# 3            0.392523           3990        36  0.300000
# 4            0.392523           8487        48  0.309353
# ..                ...            ...       ...       ...
# 795          0.120253           1237         6  0.213953
# 796          0.479452           1333        24  0.309353
# 797          0.120253           2515        18  0.328859
# 798          0.479452           8471        18  0.466667
# 799          0.120253           3029        15  0.309353
#
# [800 rows x 9 columns]

# %%
for col in categorical_cols:
    print(col,train_data[col].unique())
# Out:
# Job [0.28962818 0.37499998 0.34782609 0.29113924]
# Sex [0.27404719 0.35742972]
# Housing [0.40697674 0.25964912 0.39583333]
# Saving accounts [0.16666667 0.36421053 0.33333333 0.12195122 0.16      ]
# Checking account [0.47945205 0.12025316 0.39252336 0.25490196]
# Purpose [0.30935252 0.21395349 0.32885906 0.3        0.46666667 0.38888889
#  0.33311024 0.32911392]
# Age [0.25657895 0.26174497 0.35273973 0.34482759]

# %%
# train_data['Housing'] = train_data['Housing'].apply(lambda x: 0 if x == 'free' else (2 if x == 'own' else 1))
# train_data['Saving accounts'] = train_data['Saving accounts'].apply(lambda x: 2 if x == 'nan' 
#                                                                     else(0 if x == 'little' 
#                                                                     else(1 if x == 'moderate'
#                                                                     else(3 if x == 'quite rich' 
#                                                                     else 4))))
                                                                    
# train_data['Checking account'] = train_data['Checking account'].apply(lambda x: 2 if x == 'nan' 
#                                                                     else(0 if x == 'little' 
#                                                                     else(1 if x == 'moderate'
#                                                                     else(3 if x == 'quite rich' 
#                                                                     else 4))))

# %%
# test_data['Housing'] = test_data['Housing'].apply(lambda x: 0 if x == 'free' else (2 if x == 'own' else 1))
# test_data['Saving accounts'] = test_data['Saving accounts'].apply(lambda x: 0 if x == 'nan' 
#                                                                     else(1 if x == 'little' 
#                                                                     else(2 if x == 'moderate'
#                                                                     else(3 if x == 'quite rich' 
#                                                                     else 4))))
                                                                    
# test_data['Checking account'] = test_data['Checking account'].apply(lambda x: 0 if x == 'nan' 
#                                                                     else(1 if x == 'little' 
#                                                                     else(2 if x == 'moderate'
#                                                                     else(3 if x == 'quite rich' 
#                                                                     else 4))))

# %%
# train_data['Purpose'] = train_data['Purpose'].apply(lambda x: 0 if x == 'education' 
#                                                                     else(2 if x == 'radio/TV'                                                             
#                                                                     else 1))
# test_data['Purpose'] = test_data['Purpose'].apply(lambda x: 0 if x == 'education' 
#                                                                 else(2 if x == 'radio/TV'                                                             
#                                                                 else 1))

# %%
# train_data['Sex'] = train_data['Sex'].apply(lambda x: 0 if x == 'female' else 1)
# test_data['Sex'] = test_data['Sex'].apply(lambda x: 0 if x == 'female' else 1)

# %% [markdown]
# Scale lại bộ dữ liệu và sử dụng smote để sinh ra thêm dữ liệu

# %%
scaler = StandardScaler().fit(train_data[numeric_cols])
train_data[numeric_cols] = scaler.transform(train_data[numeric_cols])
train_data, train_labels = SMOTE().fit_resample(train_data, train_labels)

train_data
# Out:
#            Age       Sex       Job   Housing  Saving accounts  \
# 0     0.256579  0.274047  0.289628  0.406977         0.166667
# 1     0.261745  0.274047  0.289628  0.259649         0.364211
# 2     0.352740  0.274047  0.289628  0.259649         0.364211
# 3     0.352740  0.357430  0.375000  0.259649         0.166667
# 4     0.352740  0.357430  0.289628  0.259649         0.166667
# ...        ...       ...       ...       ...              ...
# 1115  0.352740  0.322297  0.291139  0.259649         0.346343
# 1116  0.261745  0.274047  0.290256  0.316217         0.364211
# 1117  0.352740  0.274438  0.289901  0.259649         0.364211
# 1118  0.268008  0.346631  0.289628  0.277286         0.166667
# 1119  0.352740  0.274047  0.315295  0.324624         0.346951
#
#       Checking account  Credit amount  Duration   Purpose
# 0             0.479452       1.925766  1.289592  0.309353
# 1             0.120253      -0.892853 -0.742595  0.213953
# 2             0.479452       0.816433  1.289592  0.328859
# 3             0.392523       0.299568  1.289592  0.300000
# 4             0.392523       1.982655  2.305686  0.309353
# ...                ...            ...       ...       ...
# 1115          0.392523      -0.904688 -0.742595  0.309353
# 1116          0.479452      -0.936233 -0.742595  0.374698
# 1117          0.391247      -0.137398  1.289592  0.309444
# 1118          0.120253       1.070165  0.207701  0.226309
# 1119          0.430861      -0.658416 -0.996618  0.309353
#
# [1120 rows x 9 columns]

# %%
test_data[numeric_cols] = scaler.transform(test_data[numeric_cols])

# %%
# feat_weight = np.array([1,1,0.5,1,2,2,2,1.5,1.5])
# i = 0
# for col in train_data.columns:
#     train_data[col] =  train_data[col]*feat_weight[i]
#     test_data[col] =  test_data[col]*feat_weight[i]
#     i+=1

# %%
train_data
# Out:
#            Age       Sex       Job   Housing  Saving accounts  \
# 0     0.256579  0.274047  0.289628  0.406977         0.166667
# 1     0.261745  0.274047  0.289628  0.259649         0.364211
# 2     0.352740  0.274047  0.289628  0.259649         0.364211
# 3     0.352740  0.357430  0.375000  0.259649         0.166667
# 4     0.352740  0.357430  0.289628  0.259649         0.166667
# ...        ...       ...       ...       ...              ...
# 1115  0.352740  0.322297  0.291139  0.259649         0.346343
# 1116  0.261745  0.274047  0.290256  0.316217         0.364211
# 1117  0.352740  0.274438  0.289901  0.259649         0.364211
# 1118  0.268008  0.346631  0.289628  0.277286         0.166667
# 1119  0.352740  0.274047  0.315295  0.324624         0.346951
#
#       Checking account  Credit amount  Duration   Purpose
# 0             0.479452       1.925766  1.289592  0.309353
# 1             0.120253      -0.892853 -0.742595  0.213953
# 2             0.479452       0.816433  1.289592  0.328859
# 3             0.392523       0.299568  1.289592  0.300000
# 4             0.392523       1.982655  2.305686  0.309353
# ...                ...            ...       ...       ...
# 1115          0.392523      -0.904688 -0.742595  0.309353
# 1116          0.479452      -0.936233 -0.742595  0.374698
# 1117          0.391247      -0.137398  1.289592  0.309444
# 1118          0.120253       1.070165  0.207701  0.226309
# 1119          0.430861      -0.658416 -0.996618  0.309353
#
# [1120 rows x 9 columns]

# %%
test_data
# Out:
#           Age       Sex       Job   Housing  Saving accounts  \
# 0    0.261745  0.274047  0.289628  0.259649         0.121951
# 1    0.261745  0.274047  0.347826  0.259649         0.364211
# 2    0.256579  0.274047  0.289628  0.259649         0.364211
# 3    0.261745  0.274047  0.289628  0.259649         0.364211
# 4    0.352740  0.274047  0.291139  0.259649         0.160000
# ..        ...       ...       ...       ...              ...
# 195  0.256579  0.274047  0.289628  0.406977         0.364211
# 196  0.256579  0.274047  0.289628  0.259649         0.166667
# 197  0.352740  0.274047  0.289628  0.259649         0.364211
# 198  0.261745  0.274047  0.289628  0.259649         0.166667
# 199  0.261745  0.274047  0.347826  0.259649         0.333333
#
#      Checking account  Credit amount  Duration   Purpose
# 0            0.392523      -0.477788 -0.234548  0.329114
# 1            0.392523      -0.497625 -0.742595  0.309353
# 2            0.479452      -0.810513  0.273499  0.213953
# 3            0.479452      -0.032034 -0.234548  0.329114
# 4            0.392523      -0.250607  0.527522  0.213953
# ..                ...            ...       ...       ...
# 195          0.479452       1.470655  2.305686  0.328859
# 196          0.392523      -0.285414 -0.234548  0.329114
# 197          0.120253      -0.721437 -0.742595  0.213953
# 198          0.479452       1.182843  0.781545  0.328859
# 199          0.120253      -0.598303  0.019475  0.328859
#
# [200 rows x 9 columns]

# %% [markdown]
# Thực hiện train model

# %%
gnb = GaussianNB()
gnb.fit(train_data,train_labels)
# Out:
# GaussianNB()

# %%
knn = KNeighborsClassifier(n_neighbors=7 ,weights='distance')
knn.fit(train_data, train_labels)
# Out:
# KNeighborsClassifier(n_neighbors=10, weights='distance')

# %% [markdown]
# Dự đoán và kết quả

# %%
predgnb = gnb.predict(test_data)
# print(predgnb,len(np.where(predgnb==1)[0]))
print(classification_report(y_pred=predgnb, y_true = test_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.69      0.77       140
#            1       0.51      0.75      0.61        60
#
#     accuracy                           0.71       200
#    macro avg       0.69      0.72      0.69       200
# weighted avg       0.76      0.71      0.72       200

# %%
predknn = knn.predict(test_data)
# print(predknn,len(np.where(predknn==1)[0]))
print(classification_report(y_pred=predknn, y_true = test_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.66      0.74       140
#            1       0.47      0.68      0.55        60
#
#     accuracy                           0.67       200
#    macro avg       0.65      0.67      0.65       200
# weighted avg       0.72      0.67      0.68       200
